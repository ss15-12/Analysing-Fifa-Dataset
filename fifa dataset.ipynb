# %%
import numpy as np 
import pandas as pd

# %%
foot=pd.read_csv('C:\\Users\\shash\\Downloads\\results.csv')
foot.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
foot.shape
# Out:
# (43752, 9)

# %%
foot.head(20)
# Out:
#           date         home_team away_team  home_score  away_score tournament  \
# 0   1872-11-30          Scotland   England           0           0   Friendly
# 1   1873-03-08           England  Scotland           4           2   Friendly
# 2   1874-03-07          Scotland   England           2           1   Friendly
# 3   1875-03-06           England  Scotland           2           2   Friendly
# 4   1876-03-04          Scotland   England           3           0   Friendly
# 5   1876-03-25          Scotland     Wales           4           0   Friendly
# 6   1877-03-03           England  Scotland           1           3   Friendly
# 7   1877-03-05             Wales  Scotland           0           2   Friendly
# 8   1878-03-02          Scotland   England           7           2   Friendly
# 9   1878-03-23          Scotland     Wales           9           0   Friendly
# 10  1879-01-18           England     Wales           2           1   Friendly
# ...

# %%
foot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43752 entries, 0 to 43751
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        43752 non-null  object
#  1   home_team   43752 non-null  object
#  2   away_team   43752 non-null  object
#  3   home_score  43752 non-null  int64
#  4   away_score  43752 non-null  int64
#  5   tournament  43752 non-null  object
#  6   city        43752 non-null  object
#  7   country     43752 non-null  object
#  8   neutral     43752 non-null  bool
# dtypes: bool(1), int64(2), object(6)
# memory usage: 1.7+ MB

# %%
#Checking how many columns have null values
[col for col in foot.columns if foot[col].isnull().sum() > 0]
# Out:
# []

# %%
groupby_hometeam=foot.groupby('home_team')

# %%
groupby_hometeam.size()
# Out:
# home_team
# Abkhazia          18
# Afghanistan       42
# Albania          187
# Alderney           7
# Algeria          300
#                 ...
# Yugoslavia       190
# Zambia           311
# Zanzibar          58
# Zimbabwe         200
# Åland Islands     27
# Length: 306, dtype: int64

# %%
groupby_awayteam=foot.groupby('away_team')

# %%
groupby_awayteam.size()
# Out:
# away_team
# Abkhazia          10
# Afghanistan       79
# Albania          169
# Alderney          12
# Algeria          228
#                 ...
# Yugoslavia       291
# Zambia           435
# Zanzibar         147
# Zimbabwe         280
# Åland Islands     19
# Length: 303, dtype: int64

# %%
totalm=groupby_awayteam.size()+groupby_hometeam.size()

# %%
totalm
# Out:
# Abkhazia          28.0
# Afghanistan      121.0
# Albania          356.0
# Alderney          19.0
# Algeria          528.0
#                  ...
# Yugoslavia       481.0
# Zambia           746.0
# Zanzibar         205.0
# Zimbabwe         480.0
# Åland Islands     46.0
# Length: 310, dtype: float64

# %%
foot.count()
# Out:
# date          43752
# home_team     43752
# away_team     43752
# home_score    43752
# away_score    43752
# tournament    43752
# city          43752
# country       43752
# neutral       43752
# dtype: int64

# %%
argen=groupby_hometeam.get_group('Argentina')

# %%
argen
# Out:
#              date  home_team  away_team  home_score  away_score  \
# 155    13-09-1903  Argentina    Uruguay           2           3
# 177    15-08-1905  Argentina    Uruguay           0           0
# 190    21-10-1906  Argentina    Uruguay           2           1
# 226    13-09-1908  Argentina    Uruguay           2           1
# 227    04-10-1908  Argentina    Uruguay           0           1
# ...           ...        ...        ...         ...         ...
# 42967  14-10-2021  Argentina       Peru           1           0
# 43115  16-11-2021  Argentina     Brazil           0           0
# 43263  01-02-2022  Argentina   Colombia           1           0
# 43331  25-03-2022  Argentina  Venezuela           3           0
# 43559  05-06-2022  Argentina    Estonia           5           0
#
#                          tournament          city    country  neutral
# 155                        Friendly  Buenos Aires  Argentina    False
# ...

# %%
plt.figure(figsize=(8,25))
sns.scatterplot(data=argen,x='away_score',y='away_team')

# %%
list1=[]
for i in totalm:
    list.append(i)

# %%
list2=[]
for i in groupby_awayteam:
    list2.append(i)

# %%
list2[1][0]
# Out:
# 'Afghanistan'

# %%
df=pd.DataFrame(list2)

# %%
df
# Out:
#                  0                                                  1
# 0         Abkhazia               date        home_team away_team  ...
# 1      Afghanistan               date     home_team    away_team  ...
# 2          Albania               date   home_team away_team  home_...
# 3         Alderney               date         home_team away_team ...
# 4          Algeria               date     home_team away_team  hom...
# ..             ...                                                ...
# 298     Yugoslavia               date       home_team   away_team ...
# 299         Zambia               date    home_team away_team  home...
# 300       Zanzibar               date home_team away_team  home_sc...
# 301       Zimbabwe               date     home_team away_team  hom...
# 302  Åland Islands               date      home_team      away_tea...
#
# [303 rows x 2 columns]

# %%
df[0]
# Out:
# 0           Abkhazia
# 1        Afghanistan
# 2            Albania
# 3           Alderney
# 4            Algeria
#            ...
# 298       Yugoslavia
# 299           Zambia
# 300         Zanzibar
# 301         Zimbabwe
# 302    Åland Islands
# Name: 0, Length: 303, dtype: object

# %%
list3=[]
for i in df[0]:
    list3.append(i)

# %%
list3
# Out:
# ['Abkhazia',
#  'Afghanistan',
#  'Albania',
#  'Alderney',
#  'Algeria',
#  'American Samoa',
#  'Andalusia',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'Arameans Suryoye',
#  'Argentina',
#  'Armenia',
#  'Artsakh',
#  'Aruba',
#  'Asturias',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barawa',
#  'Barbados',
#  'Basque Country',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bonaire',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brittany',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Cascadia',
#  'Catalonia',
#  'Cayman Islands',
#  'Central African Republic',
#  'Central Spain',
#  'Chad',
#  'Chagos Islands',
#  'Chameria',
#  'Chile',
#  'China PR',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Cook Islands',
#  'Corsica',
# ...

# %%
list
# Out:
# [28.0,
#  121.0,
#  356.0,
#  19.0,
#  528.0,
#  48.0,
#  13.0,
#  190.0,
#  372.0,
#  68.0,
#  204.0,
#  10.0,
#  1011.0,
#  234.0,
#  11.0,
#  127.0,
#  nan,
#  534.0,
#  817.0,
#  271.0,
#  47.0,
#  517.0,
#  233.0,
#  12.0,
#  275.0,
#  58.0,
#  277.0,
#  799.0,
#  89.0,
#  274.0,
#  165.0,
#  81.0,
#  487.0,
#  25.0,
#  248.0,
#  290.0,
#  1014.0,
#  98.0,
#  12.0,
#  75.0,
#  696.0,
#  413.0,
#  198.0,
#  239.0,
#  558.0,
#  410.0,
#  nan,
#  187.0,
#  7.0,
#  48.0,
#  98.0,
#  104.0,
#  2.0,
#  114.0,
#  11.0,
#  5.0,
#  793.0,
#  608.0,
#  578.0,
#  74.0,
#  377.0,
#  44.0,
#  9.0,
#  645.0,
#  9.0,
#  nan,
#  349.0,
#  353.0,
#  343.0,
#  388.0,
#  328.0,
#  498.0,
#  479.0,
#  7.0,
#  827.0,
#  98.0,
#  191.0,
#  123.0,
#  544.0,
#  666.0,
#  547.0,
#  17.0,
#  1042.0,
#  142.0,
#  72.0,
#  507.0,
#  244.0,
#  383.0,
#  29.0,
#  250.0,
#  8.0,
#  225.0,
#  774.0,
#  870.0,
#  163.0,
#  30.0,
#  361.0,
#  9.0,
#  232.0,
#  267.0,
#  298.0,
#  980.0,
#  621.0,
#  122.0,
# ...

# %%
df2=pd.DataFrame(totalm)

# %%
df2
# Out:
#                    0
# Abkhazia        28.0
# Afghanistan    121.0
# Albania        356.0
# Alderney        19.0
# Algeria        528.0
# ...              ...
# Yugoslavia     481.0
# Zambia         746.0
# Zanzibar       205.0
# Zimbabwe       480.0
# Åland Islands   46.0
#
# [310 rows x 1 columns]

# %%
plt.figure(figsize=(50,30))
sns.scatterplot(data=df2[:50],s=200,c='green')
